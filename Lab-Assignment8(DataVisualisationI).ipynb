# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhiKate09/DSBDA-Lab_Assignments/blob/main/Lab-Assignment8(DataVisualisationI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
dataset = sns.load_dataset('titanic')
print(dataset.head())
import matplotlib.pyplot as plt
import pandas as pd
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(8, 2))
sns.histplot(x=dataset['age'], bins=10, kde=True)
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind ='scatter')

# %%
plt.figure(figsize=(8, 2))
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind = 'hex')

# %%
plt.figure(figsize=(8, 2))
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
plt.figure(figsize=(8, 3))
sns.barplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 3))
sns.boxplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='sex', y='age', data=dataset, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 2))
sns.violinplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8,2))
sns.violinplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 2))
sns.stripplot(x='sex', y='age', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 2))
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(8, 2))
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 22.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
titanic_numeric = dataset.copy()
titanic_numeric = pd.get_dummies(titanic_numeric, drop_first=True)
corr = titanic_numeric.corr()
plt.figure(figsize=(16,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.histplot(dataset['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
